# %% [markdown]
# <a href="https://colab.research.google.com/github/isali28/HashingLab-Attack-/blob/main/Hashing_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from hashlib import blake2b, md5

# %%
h=blake2b()

# %%
h.update(b'De-Icing girl')

# %%
blake_hash=h.hexdigest()
print(blake_hash)
# Out:
# 949d5c6344db5f786301ff924c6589e0ea494cbc5ff42e5fd6fd7e499cb2c181eafa2ba8842be3ab39f0f70ad9aafe8d6ad955dece1fb09129d2811a056e7be3

# %%
m=md5()

# %%
m.update(b'De-Icing girl')
md5_hash=m.hexdigest()
print(md5_hash)
# Out:
# 56f166220338746b6185e59f4c90b9cc

# %%
md5_hash_example='0a6c36ddd62eee77a015d0592e009ce9'

# %% [markdown]
# Hash simulation: md5_hash

# %%
pip install bcrypt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import timeit
import bcrypt
import itertools

# %%
dict_path='/apache.txt'
with open(dict_path, 'r') as file:
  for line in file:
    word=line.strip()
    hashed_word=md5_hash_example
    if hashed_word==word:
      print("welcome james bond :)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-401387590.py in <cell line: 0>()
#       1 dict_path='/apache.txt'
# ----> 2 with open(dict_path, 'r') as file:
#       3   for line in file:
#       4     word=line.strip()
#       5     hashed_word=md5_hash_example
#
# FileNotFoundError: [Errno 2] No such file or directory: '/apache.txt'
